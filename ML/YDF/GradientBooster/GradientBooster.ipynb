# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewrocke/MSc-code/blob/main/GradientBooster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ydf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import matplotlib.pyplot as plt


ds = pd.read_csv("output_left_singlelabel_add_del_NST.csv")
print("total dataframe :",ds.shape)
#X=ds['sAddress','rAddress']
#y= ds['IT_B_Label']

#X_train, X_test, y_train,  y_test = train_test_split(X,y ,
                          #random_state=104,
                          #train_size=0.8, shuffle=True)

mask = np.random.rand(len(ds)) < 0.8
train_ds = ds[mask]
test_ds = ds[~mask]

#test_ds = ds.tf.take(1000)
#train_ds = ds.tf.skip(1000)
print("train_ds count :" ,len(train_ds))
#test_ds = pd.read_csv("ML Test/output_left.csv")
print("test_ds count :" , len(test_ds))
#train_ds = pd.read_csv("ML Test/output_left_23.csv")
print("train_ds :" ,train_ds.head(5))
#test_ds = pd.read_csv("ML Test/output_left.csv")
print("test_ds :" ,test_ds.head(5))
model = ydf.GradientBoostedTreesLearner(label="NST_B_Label").train(train_ds)
model.describe()
print(model.evaluate(test_ds))

# Get model predictions for the test set
pred = model.predict(test_ds) # This line is crucial


test_labels = pd.to_numeric(test_ds['NST_B_Label'], errors='coerce') # Convert to numeric, handle errors
pred_labels = pd.to_numeric(pred, errors='coerce')                 # Convert to numeric, handle errors

pred_labels = (pred >= 0.5).astype(int) # Apply threshold and convert to integers

# Now use the converted labels for accuracy calculation
accuracy = accuracy_score(test_labels, pred_labels)
precision = precision_score(test_labels, pred_labels)
recall = recall_score(test_labels, pred_labels)
f1 = f1_score(test_labels, pred_labels)


print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(test_labels, pred_labels)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Analyse a model (e.g. partial dependence plot, variable importance)
model.analyze(test_ds)

# Benchmark the inference speed of a model
model.benchmark(test_ds)
#print(model.benchmark(test_ds))
#model.analyze(test_ds, sampling=0.1)
model.save("my_model")

loaded_model = ydf.load_model("my_model")
# Out:
# total dataframe : (8533, 52)
# train_ds count : 6835
# test_ds count : 1698
# train_ds :         start         end  startOffset  endOffset  duration  sPackets  \
# 1  1678440575  1678440575     1.023529   1.023533  0.000005         4
# 2  1678440576  1678440576     2.047534   2.047539  0.000006         4
# 4  1678440581  1678440581     7.167439   7.167443  0.000005         4
# 5  1678440575  1678440575     0.887215   0.887215  0.000001         1
# 6  1678440575  1678440575     0.889012   0.889012  0.000001         1
#
#    rPackets  sBytesSum  rBytesSum  sBytesMax  ...  rWinTCP  sFragmentRate  \
# 1         0        240          0       60.0  ...      NaN            NaN
# 2         0        240          0       60.0  ...      NaN            NaN
# 4         0        240          0       60.0  ...      NaN            NaN
# 5         0         40          0       40.0  ...      NaN            0.0
# 6         0         40          0       40.0  ...      NaN            0.0
#
#    rFragmentRate  sAckDelayMax  rAckDelayMax  sAckDelayMin  rAckDelayMin  \
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
# 5            NaN           NaN           NaN           NaN           NaN
# 6            NaN           NaN           NaN           NaN           NaN
#
#    sAckDelayAvg  rAckDelayAvg  NST_B_Label
# 1           NaN           NaN            0
# 2           NaN           NaN            0
# 4           NaN           NaN            0
# 5           NaN           NaN            0
# 6           NaN           NaN            0
#
# [5 rows x 52 columns]
# test_ds :          start         end  startOffset  endOffset  duration  sPackets  \
# 0   1678440574  1678440574     0.000000   0.000004  0.000005         4
# 3   1678440580  1678440580     6.143809   6.143813  0.000005         4
# 9   1678440587  1678440587    13.311332  13.311336  0.000005         4
# 10  1678440588  1678440588    14.335211  14.335215  0.000005         4
# 16  1678440595  1678440595    20.478969  20.478974  0.000006         4
#
#     rPackets  sBytesSum  rBytesSum  sBytesMax  ...  rWinTCP  sFragmentRate  \
# 0          0        240          0       60.0  ...      NaN            NaN
# 3          0        240          0       60.0  ...      NaN            NaN
# 9          0        240          0       60.0  ...      NaN            NaN
# 10         0        240          0       60.0  ...      NaN            NaN
# 16         0        240          0       60.0  ...      NaN            NaN
#
#     rFragmentRate  sAckDelayMax  rAckDelayMax  sAckDelayMin  rAckDelayMin  \
# 0             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 9             NaN           NaN           NaN           NaN           NaN
# 10            NaN           NaN           NaN           NaN           NaN
# 16            NaN           NaN           NaN           NaN           NaN
#
#     sAckDelayAvg  rAckDelayAvg  NST_B_Label
# 0            NaN           NaN            0
# 3            NaN           NaN            0
# 9            NaN           NaN            0
# 10           NaN           NaN            0
# 16           NaN           NaN            0
#
# [5 rows x 52 columns]
# Train model on 6835 examples
# Model trained in 0:00:07.953741
# accuracy: 0.956419
# confusion matrix:
#     label (row) \ prediction (col)
#     +-----+-----+-----+
#     |     |   0 |   1 |
#     +-----+-----+-----+
#     |   0 | 762 |  26 |
#     +-----+-----+-----+
#     |   1 |  48 | 862 |
#     +-----+-----+-----+
# characteristics:
#     name: '1' vs others
#     ROC AUC: 0.993135
#     PR AUC: 0.994879
#     Num thresholds: 958
# loss: 0.103662
# num examples: 1698
# num examples (weighted): 1698
#
# Accuracy: 0.96
# Precision: 0.97
# Recall: 0.95
# F1 Score: 0.96
# Accuracy: 0.96
# Precision: 0.97
# Recall: 0.95
# F1 Score: 0.96

# %%
import ydf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import matplotlib.pyplot as plt


ds = pd.read_csv("output_left_NST.csv")
print("total dataframe :",ds.shape)
#X=ds['sAddress','rAddress']
#y= ds['IT_B_Label']

#X_train, X_test, y_train,  y_test = train_test_split(X,y ,
                          #random_state=104,
                          #train_size=0.8, shuffle=True)

mask = np.random.rand(len(ds)) < 0.8
train_ds = ds[mask]
test_ds = ds[~mask]

#test_ds = ds.tf.take(1000)
#train_ds = ds.tf.skip(1000)
print("train_ds count :" ,len(train_ds))
#test_ds = pd.read_csv("ML Test/output_left.csv")
print("test_ds count :" , len(test_ds))
#train_ds = pd.read_csv("ML Test/output_left_23.csv")
print("train_ds :" ,train_ds.head(5))
#test_ds = pd.read_csv("ML Test/output_left.csv")
print("test_ds :" ,test_ds.head(5))
model = ydf.GradientBoostedTreesLearner(label="NST_B_Label").train(train_ds)
model.describe()
print(model.evaluate(test_ds))

# Get model predictions for the test set
pred = model.predict(test_ds) # This line is crucial


test_labels = pd.to_numeric(test_ds['NST_B_Label'], errors='coerce') # Convert to numeric, handle errors
pred_labels = pd.to_numeric(pred, errors='coerce')                 # Convert to numeric, handle errors

pred_labels = (pred >= 0.5).astype(int) # Apply threshold and convert to integers

# Now use the converted labels for accuracy calculation
accuracy = accuracy_score(test_labels, pred_labels)
precision = precision_score(test_labels, pred_labels)
recall = recall_score(test_labels, pred_labels)
f1 = f1_score(test_labels, pred_labels)


print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(test_labels, pred_labels)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Analyse a model (e.g. partial dependence plot, variable importance)
model.analyze(test_ds)

# Benchmark the inference speed of a model
model.benchmark(test_ds)
#print(model.benchmark(test_ds))
#model.analyze(test_ds, sampling=0.1)
model.save("my_model")

loaded_model = ydf.load_model("my_model")
# Out:
# total dataframe : (8533, 61)
# train_ds count : 6825
# test_ds count : 1708
# train_ds :             sAddress           rAddress              sMACs              rMACs  \
# 1  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff
# 3  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff
# 4  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff
# 6       198.18.134.2         224.0.0.22  00:07:7c:88:6e:63  01:00:5e:00:00:16
# 7  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff
#
#            sIPs        rIPs protocol startDate  endDate         start  ...  \
# 1           NaN         NaN      ARP   29:35.1  29:35.1  1.678441e+09  ...
# 3           NaN         NaN      ARP   29:40.2  29:40.2  1.678441e+09  ...
# 4           NaN         NaN      ARP   29:41.2  29:41.2  1.678441e+09  ...
# 6  198.18.134.2  224.0.0.22   IPV4-2   29:35.0  29:35.0  1.678441e+09  ...
# 7           NaN         NaN      ARP   29:42.3  29:42.3  1.678441e+09  ...
#
#    rWinTCP  sFragmentRate  rFragmentRate  sAckDelayMax  rAckDelayMax  \
# 1      NaN            NaN            NaN           NaN           NaN
# 3      NaN            NaN            NaN           NaN           NaN
# 4      NaN            NaN            NaN           NaN           NaN
# 6      NaN            0.0            NaN           NaN           NaN
# 7      NaN            NaN            NaN           NaN           NaN
#
#    sAckDelayMin  rAckDelayMin  sAckDelayAvg  rAckDelayAvg  NST_B_Label
# 1           NaN           NaN           NaN           NaN            0
# 3           NaN           NaN           NaN           NaN            0
# 4           NaN           NaN           NaN           NaN            0
# 6           NaN           NaN           NaN           NaN            0
# 7           NaN           NaN           NaN           NaN            0
#
# [5 rows x 61 columns]
# test_ds :              sAddress           rAddress              sMACs  \
# 0   b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c
# 2   b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c
# 5       198.18.134.99         224.0.0.22  00:24:9b:6d:b8:89
# 9   b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c
# 10  b8:27:eb:15:88:9c  ff:ff:ff:ff:ff:ff  b8:27:eb:15:88:9c
#
#                 rMACs           sIPs        rIPs protocol startDate  endDate  \
# 0   ff:ff:ff:ff:ff:ff            NaN         NaN      ARP   29:34.1  29:34.1
# 2   ff:ff:ff:ff:ff:ff            NaN         NaN      ARP   29:36.1  29:36.1
# 5   01:00:5e:00:00:16  198.18.134.99  224.0.0.22   IPV4-2   29:35.0  29:35.0
# 9   ff:ff:ff:ff:ff:ff            NaN         NaN      ARP   29:47.4  29:47.4
# 10  ff:ff:ff:ff:ff:ff            NaN         NaN      ARP   29:48.4  29:48.4
#
#            start  ...  rWinTCP  sFragmentRate  rFragmentRate  sAckDelayMax  \
# 0   1.678441e+09  ...      NaN            NaN            NaN           NaN
# 2   1.678441e+09  ...      NaN            NaN            NaN           NaN
# 5   1.678441e+09  ...      NaN            0.0            NaN           NaN
# 9   1.678441e+09  ...      NaN            NaN            NaN           NaN
# 10  1.678441e+09  ...      NaN            NaN            NaN           NaN
#
#     rAckDelayMax  sAckDelayMin  rAckDelayMin  sAckDelayAvg  rAckDelayAvg  \
# 0            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 5            NaN           NaN           NaN           NaN           NaN
# 9            NaN           NaN           NaN           NaN           NaN
# 10           NaN           NaN           NaN           NaN           NaN
#
#     NST_B_Label
# 0             0
# 2             0
# 5             0
# 9             0
# 10            0
#
# [5 rows x 61 columns]
# Train model on 6825 examples
# Model trained in 0:00:08.654715
# accuracy: 0.981265
# confusion matrix:
#     label (row) \ prediction (col)
#     +-----+-----+-----+
#     |     |   0 |   1 |
#     +-----+-----+-----+
#     |   0 | 797 |   6 |
#     +-----+-----+-----+
#     |   1 |  26 | 879 |
#     +-----+-----+-----+
# characteristics:
#     name: '1' vs others
#     ROC AUC: 0.99542
#     PR AUC: 0.997099
#     Num thresholds: 748
# loss: 0.061634
# num examples: 1708
# num examples (weighted): 1708
#
# Accuracy: 0.98
# Precision: 0.99
# Recall: 0.97
# F1 Score: 0.98
# Accuracy: 0.98
# Precision: 0.99
# Recall: 0.97
# F1 Score: 0.98
